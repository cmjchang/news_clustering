# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Jun 24 12:49:04 2018

@author: Jimmy
"""

import pandas as pd
import numpy as np
import requests
import re
import glob
#from gensim.models.word2vec import Word2Vec
import os

import jieba
import jieba.analyse
from hanziconv import HanziConv

from functools import reduce
from bs4 import BeautifulSoup

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

jieba_path = r'C:\Users\Jimmy\Anaconda3\Lib\site-packages\jieba'

#load jieba dictionary
jieba.set_dictionary(os.path.join(jieba_path, 'dict.txt'))

list_url = glob.glob(r'C:\Users\Jimmy\Desktop\Python\Googleresult\CCCC\1?.html')
#list_url = [url1,url2,url3]

def read_from_file(list_url):
    google_df = pd.DataFrame(columns = ['heading', 'content', 'google_tag', 'extract_tag'])
    for url in list_url:
        with open(url, 'rb') as f:
            soup = BeautifulSoup(f.read().decode('utf8'), features = "html.parser")
        for articles in soup.find_all('div', class_='g'):
            if not re.search(re.compile('youtube\.com|img|books.google.com'), articles.prettify()):
                heading = articles.find('a').text
                content = articles.find('span', class_='st').text
                #replace date and  ...
                cleanr = re.compile(u'[0-9]{1,2}[ ]?月[0-9]{1,2}[ ]?日|\.{3}|[.]{3}|\\xa0|On\.cc|i-Cable|China Press|\.\.')
                heading = re.sub(cleanr, '', heading)
                content = re.sub(cleanr, '', content)
                google_tag = ''
                for tag in articles.find('div', class_='s').find_all('b')[1:]:
                    if tag != r'...':
                        google_tag = google_tag + ' ' + tag.text
                row = pd.Series([heading,content,google_tag,'0'], index = ['heading', 'content', 'google_tag', 'extract_tag'])
                google_df = google_df.append(row,ignore_index=True)
    return google_df

#creating a DF contain heading, content, extract tag,

def google_content(list_url):
    google_df = pd.DataFrame(columns = ['heading', 'content', 'google_tag', 'extract_tag'])
    for url in list_url:
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "lxml")
        for articles in soup.find_all('div', class_='g'):
            if not re.search(re.compile('youtube\.com|img|books.google.com'),articles.prettify()):
                heading = articles.find('a').text
                content = articles.find('span', class_='st').text
                #replace date and  ...
                cleanr = re.compile(u'[0-9]{1,2}[ ]?月[0-9]{1,2}[ ]?日|\.{3}|[.]{3}|\\xa0|On\.cc|i-Cable|China Press|\.\.')
                heading = re.sub(cleanr, '', heading)
                content = re.sub(cleanr, '', content)
                google_tag = ''
                for tag in articles.find('div', class_='s').find_all('b')[1:]:
                    if tag != r'...':
                        google_tag = google_tag + ' ' + tag.text
                row = pd.Series([heading,content,google_tag,'0'], index = ['heading', 'content', 'google_tag', 'extract_tag'])
                google_df = google_df.append(row,ignore_index=True)
    return google_df

# text cutting by jieba, convert to traditional word at the same time
    
def sim_to_trad(df):
    df[['heading', 'content']] = df[['heading','content']].applymap(lambda x : HanziConv.toSimplified(x))
    
def cleaning(df):
    cleanr1 = re.compile(u'[0-9]{1,2}月[0-9]{1,2}日|\.{3}|[0-9] hours ago')
    cleanr2 = re.compile(u'[0-9]{1} day[s]? ago|[0-9]{1,2} hour[s]? ago|[0-9]{1,2} min[s]? ago')
    df[['heading', 'content']] = df[['heading','content']].applymap(lambda x: re.sub(cleanr1, '', x))
    df[['heading', 'content']] = df[['heading','content']].applymap(lambda x: re.sub(cleanr2, 'recent', x))
#    aka = re.compile(u'中國交建|中交建|中交|中國交通建設集團有限公司|中國交通建設')
#    df[['heading','content']] = df[['heading','content']].applymap(lambda x: re.sub(aka, '中交', x))

def extract_tag(df):
    for index in df.index:
        cut_heading = jieba.analyse.extract_tags(HanziConv.toSimplified(df.loc[index,'heading']), topK =50)
        cut_content = jieba.analyse.extract_tags(HanziConv.toSimplified(df.loc[index,'content']), topK =50)
        df.loc[index,'extract_tag'] = reduce(lambda x,y: x + ' ' + y,cut_heading + cut_content)
        df.loc[index,'len_cut_heading'] = len(cut_heading)
        df.loc[index,'len_cut_content'] = len(cut_content)
        #print(df.loc[index,'extract_tag'])

def tfidf(df):
    vectorizer = CountVectorizer()
    return vectorizer.fit_transform(df['extract_tag'])

def tfidf_2(df):
    vectorizer = TfidfVectorizer()
    return vectorizer.fit_transform(df['extract_tag'])

def svd(tfidf):
    svd = TruncatedSVD(n_components=int(tfidf.shape[1]/25), n_iter=7, random_state=42)
    matrix = svd.fit_transform(tfidf)
    print(svd.explained_variance_ratio_.sum())  
    return matrix

def nmf(tfidf):
    model = NMF(n_components=int(60), random_state=42, max_iter=20)
    matrix = model.fit_transform(tfidf)
    return matrix

def KM_clustering_selection(df, matrix):
    KM = KMeans(n_jobs=-1)
    KM = KMeans(random_state=42)
    classifier = GridSearchCV(KM,
                                    {"n_clusters": np.logspace(np.log10(df.shape[0] / 100),
                                                               np.log10(df.shape[0] / 1.5), 5).astype(int)},
                                    n_jobs=-1)
    classifier.fit(matrix)
    df['labels'] = classifier.best_estimator_.labels_
    df['distance_point_to_cluster'] = classifier.best_estimator_.transform(matrix).min(axis=1)
    print("inertia {}".format(classifier.best_estimator_.inertia_))
    print("Number of Cluster {}".format(df['labels'].nunique()))
       
    
def printing_result(df):
    print(df['labels'].nunique())
    for label in df['labels'].value_counts().index[:20]:
        print('cluster {}'.format(label))
        tag = ''
        for index in df[df['labels'] == label].index:
            tag = tag + df.loc[index,'heading'] + df.loc[index,'content']
        print(google_df[google_df['labels'] == label]['distance_point_to_cluster'].mean())
        print(jieba.analyse.extract_tags(HanziConv.toSimplified(tag),topK =10))
        print(df['content'][df['labels'] == label])


google_df = read_from_file(list_url)
sim_to_trad(google_df)
cleaning(google_df)
extract_tag(google_df)
#google_tfidf = tfidf(google_df)
google_tfidf = tfidf_2(google_df)
#matrix = svd(google_tfidf)
matrix = nmf(google_tfidf)
KM_clustering_selection(google_df,matrix)
printing_result(google_df)
# Out:
# Building prefix dict from C:\Users\Jimmy\Anaconda3\Lib\site-packages\jieba\dict.txt ...
# Loading model from cache C:\Users\Jimmy\AppData\Local\Temp\jieba.u68658d17e004c479affaffef87308a74.cache
# Loading model cost 1.004 seconds.
# Prefix dict has been built succesfully.
# 662    2018年 - 中国港湾」为香港上市的中交股份公司的全资子公司，代表中交股份在国际工程市场开...
# Name: content, dtype: object
# cluster 114
# 0.031087710529985053
# ['2018', '交通', '建设', '事故现场', '中国', '交通运输', '浦口区', '处置', '建设工程', '印发']
# 375    2018年 - 11, 中国交通建设股份有限公司, 浦口区丰子河路建设工程PPP综合管廊项目...
# 408    2017年 - 各省、自治区、直辖市、新疆生产建设兵团及计划单列市交通运输厅（局、委），中国...
# 417    2011年 - 宁夏中色东方项目部起重吊装事故现场应急处置方案. 中国交通建设集团大连长兴岛...
# 435    然而，炼厂发生的责任事故所导致的人身伤害、环境破坏、亦或  边存在严重的污染风险，而且高温原...
# 461    2018年 - 该报告还点名中国交通建设公司（通过其子公司“中国港湾”）的海外经营给当地经济...
# 492     - 交通运输部昨日印发关于全面加强生态环境保护坚决打好污染防治攻坚战的实施意见，研究制定运...
# 493    2018年 -  院长朱民、资深大律师袁国强、中国交通建设董事长刘起涛、香港建筑师学会会长陈...
# Name: content, dtype: object
# cluster 398
# 0.03468929830638196
# ['中交建', '东铁', '大马', '2018', '东海岸', '新闻', '铁路', '停工', '承建商', '马来西亚']
# 228    2018年 - 中交通建设公司驳《砂报告》指控．“没抬高东海岸铁路造价” · 沈志勤：每公里...
# 319    recent - 东铁或3个月内复工~~ 停工一天损失数百万，中交建吃不消，或会点头  如果...
# 351    2018年 -  林内乡焚化厂贿弊案，官司缠讼14年，昨法院以期约贿赂罪判8年定谳。  中交...
# 463    2018年 - 大马内幕者”引述政府消息人士表示，要退出这项从吉兰丹通往巴生港口的  根据一...
# 765    2018年 - 国家公园局与中交建备忘录确保东铁不破坏森林. 分享  他指出，第一部分的环境...
# 905    recent - 财经,港股风云,消息和港股风云最新消息标题为：中交建现跌近2% 证实大马东...
# 913    2018年 - 据马来西亚《新海崃时报》（New Straits Times）昨日（4日）报...
# Name: content, dtype: object
# cluster 93
# 0.026513382274297753
# ['Aecon', '中交建', '收购', '加拿大', '2018', '建筑', 'Group', 'Inc', '否决', '加拿大政府']
# 190    2018年 -  暂录1,770万元。 加拿大政府阻止收购建筑公司Aecon 中交建：未收到...
# 229    2018年 - 中交建表示，已收到加拿大院督通知关于要求公司停止收购当地建筑公司Aecon ...
# 233    2018年 - 中企加拿大併购遇阻：中交建收购Aecon搁浅. 华尔街见闻※来源：  根据调...
# 240    2018年 - 中交建是世界上最大的工程基础建设企业之一，而计划中收购的Aecon集团 . ...
# 295    2018年 - 中交建并购Aecon遭否决，凸显加中贸易困境。  联邦创新部长贝恩(Navd...
# 778    2018年 - 中国交通建设低开后，初段曾升过近0.6%，其后无升跌。 中交建表示，已收到加...
# 866    2017年 - 重磅消息！加拿大建筑巨擘Aecon Group Inc表示，同意由中国交通建...
# Name: content, dtype: object
# cluster 30
# 0.026422220948171673
# ['港珠澳', '大桥', '中交', '工程', '沉管', '联合体', '股份', '白海豚', '管理局', '2017']
# ['丹麦', '中交建', '华企', '入围', '基建', '国安', '基于', '落空', '考虑', '2018']
# 212    中交建入围丹麦基建项目基于国安考虑华企可能落空. 2018-06-18  可能在这种背景下，...
# 242    2018年 - 中交建入围丹麦基建项目基于国安考虑华企可能落空  就丹麦政府对中资企业在当地...
# 436    2018年 - 据了解，成功入围的中国企业是中国交通建设集团，就丹麦政府对中资  对其影响力...
# 792    2018年 - 首页图片热点专题参与首发维权要闻转载录音、视频时评来稿照登时政要闻转载  中...
# 869    2018年 - 中交建入围丹麦基建项目基于国安考虑华企可能落空  越来越多，西方国家对其影响...
# Name: content, dtype: object
# cluster 9
# 0.009417616739950663
# ['加中', '美澳', '中交建', '加爱康', '自贸', '对华关系', '杂音', '中加', '关系', '冷淡']
# 339    1 - 但现在加中关系似乎冷淡下来，加政府对进一步发展对华关系更加犹豫，它阻止了中交建收购加...
# 343    但现在加中关系似乎冷淡下来，加政府对进一步发展对华关系更加犹豫，它阻止了中交建收购加爱康集团...
# 916    但现在加中关系似乎冷淡下来，加政府对进一步发展对华关系更加犹豫，它阻止了中交建收购加爱康集团...
# 917    2 - 但现在加中关系似乎冷淡下来，加政府对进一步发展对华关系更加犹豫，它阻止了中交建收购加...
# 918    1 - 但现在加中关系似乎冷淡下来，加政府对进一步发展对华关系更加犹豫，它阻止了中交建收购加...
# Name: content, dtype: object
# cluster 167
# 0.03009304480403189
# ['2018', '桥梁', '施工', '棋牌', '中交', 'IPO', '福瑞', '中交建宏峰', '斗门', '有限公司']
# 132    2018年 -  陕煤股份、中交股份以及新华保险的IPO计划迟迟未得到放行，显示了IPO  ...
# 182    2018年 - 徐楷的“仕途”从一开始就存在明显的晋升年限违规问题。根据2000年《中共江西...
# 266    福建省福瑞工程招标有限公司关于中交建宏峰集团有限公司斗门停车场调蓄池泵采购项目公开招标公告....
# 678    【摘要】：近年来桥梁坍塌事故频发,造成了严重的财产损失和人身伤亡,社会影响极大。避免桥梁坍塌...
# Name: content, dtype: object
# cluster 74
# 0.020450997145531252
# ['中交', '决策程序', '违反规定', '振华', '2017', '股份', '年度报告', '担保', '重工', '对外']
# 32    2017年 - 八、 是否存在违反规定决策程序对外提供担保的情况？ . 于本次收购前，中交股...
# 51    2018年 - 八、 是否存在违反规定决策程序对外提供担保的情况？ 否. 九、 重大风险 ....
# 52    2017年 - 八、 是否存在违反规定决策程序对外提供担保的情况？ 否  中国交建、中交股份...
# 60    2012年 - (六) 是否存在违反规定决策程序对外提供担保的情况？ 否  2008 年公司...
# Name: content, dtype: object
# cluster 39
# 0.02975458812244558
# ['2017', '修复', '苏交科', 'AECOM', '中交', '交通', '污染', '中国', '有限公司', '美通']
# 391    中国交通建设股份有限公司. China Communications  50年代后期，随着工...
# 411    2017年 - 香港2017年电/美通社/ -- AECOM 今日宣布与中国交通建设股份  ...
# 453    ，中国交通建设股份有限公司科学技术部副总经理孙宏一行赴苏交科调研。  苏交科￨ 规范和指导船...
# 872    2017年 - 中交建近期，中国交通建设股份有限公司旗下的中交公路规划设计院有限  在其业务...
# Name: content, dtype: object
# cluster 477
# 0.02811132016996888
# ['非法', '民政部', '组织', '社会', '2018', '涉嫌', '名单', '中国', '公布', '40']
# 418    2018年 - 民政部社会组织管理局公布最新一批未在民政部门登记的涉嫌非法社会组织名单。“中...
# 433    2018年 - 民政部公布第三批涉嫌非法社会组织名单.  医学协会”、“国家职业资格鉴定中心...
# 467    2018年 - 为获得取缔非法社会组织的有力证据，有关单位和个人可通过三种渠道提供  登陆中...
# 502    2018年 - 据了解，这些非法社会组织通常打着社会组织旗号，骗取大家的信任，非法开展各类会...
# Name: content, dtype: object
# cluster 27
# 0.014253755176015221
# ['阳明', '巴拿马', '哈尔滨', '大桥', '陈思敏', '央企遭', '废标', '2012', '匝道', '坍塌']
# 586    recent - 在巴拿马公共工程部（MOP）当时收到的4份报价中，中交股份这一组给出的  ...
# 592    2 - 在巴拿马公共工程部（MOP）当时收到的四份报价中，中交股份这一组给出  2012年，...
# 871    recent - 2012年，黑龙江哈尔滨阳明滩大桥发生匝道坍塌死伤事故，  基于上述证据，...
# 907    recent - 2012年，黑龙江哈尔滨阳明滩大桥发生匝道坍塌死伤事故，  基于上述证据，...
# Name: content, dtype: object
# cluster 67
# 0.020416860287957826
# ['English', '2018', '交通', '董事会', '有限公司', '建设', '集团', '中国', '央企情', '央企高管']
# 371    Many translated example sentences containing "...
# 498    2018年 - 中共背景的中国交通建设股份有限公司CCCC与大马前首相纳吉掌管的财政部达成 ...
# 526    recent -  中国建材集团有限公司党委副书记孙力实，中国华电集团有限公司董事会秘书、总...
# 529    recent -  集团有限公司董事会秘书、总经理助理办公厅主任王绪祥，中国交通建设集团有限...
# Name: content, dtype: object
# cluster 164
# 0.02784921183651396
# ['中交建', '01800', '基建', '钼业', '里昂', '留意', '港股', '低位', '十大', '洛阳']
# 205    焦点股份中交建(01800)：股价今早创逾一年低，收市跌2.7%，成交额1.85亿元。集团指...
# 264    2015年 - 另一方面，要看负债水平，中交为79%，中交建的业务多元化，主要在内地及海外从...
# 292    2017年 - 里昂：明年全球十大“爱股” 中交建及洛阳钼业上榜. 里昂发表研究报告，称明年...
# 348     -  值已回落至历史低位，下半年可留意三只基建股，包括中交建(01800)、中冶(0161...
# Name: content, dtype: object
# cluster 31
# 0.015674796097476962
# ['沥青', '混合', '搅拌', '中交', '稀浆', '封层', '摊铺机', '设备', '大事记', '西筑']
# 68     ，公司“稀浆封层车、沥青混合料搅拌设备、沥青混合料摊铺机”被授予“2012年度经开区自主创新...
# 631    ，公司“稀浆封层车、沥青混合料搅拌设备、沥青混合料摊铺机”被授予“2012年度经开区自主创新...
# 729    ，公司承担的中交股份科技研发项目“ZT600专用摊铺机”、“大型沥青混合料搅拌设备关键技术研...
# 742    ，公司承担的中交股份科技研发项目“ZT600专用摊铺机”、“大型沥青混合料搅拌设备关键技术研...
# Name: content, dtype: object
# cluster 251
# 0.024608068711012326
# ['监理', '安全', '交通', '交通运输', '2018', '水运', '工程施工', '建设', '协会', '要点']
# 370    《公路水运工程施工安全重大隐患排查要点》书末附有《中华人民共和国安全生产法》和《公路水运工程...
# 424    ISBN13：9787114065354; 出版社：人民交通出版社; 作者：中国交通建设监理...
# 447    2018年 - 各省、自治区、直辖市、新疆生产建设兵团交通运输厅（局、委），中国远洋海运、招...
# 459    重点关注 · 市州动态, 点击排行, 安全事故曝光 . 交通运输部, |, 四川省交通运输厅...
# Name: content, dtype: object
# cluster 45
# 0.027759549947927
# ['中交', '仰光', '缅甸', '时时', '股份', '媒体', 'aipin', 'me', '官网', 'bbin']
# 125    缅甸时报报道，得益于仰光地区政府成立的NYDC与中交股份的合作，该地区政府计划借助  欧洲是...
# 183    2018年 - 鹏起科技高增长“缺钙” 20亿存货23亿商誉现金流为负 · 十年重生路镜头里...
# 186     老时时彩开奖号码aipin点me马克龙访澳中国却“躺着中枪”被指对华发这警告 · 新时时 ...
# 725    外媒：阿迪达斯美国客户资料可能已被盗_1; 【环球网报导记者李慧玲】据法新社28日报导，德国...
# Name: content, dtype: object
# cluster 499
# 0.02935286346948452
# ['施工', '体验', '安全', '电建', '汉坤', '安全事故', '一站式', '威海', '新闻网', '教育']
# 346     - 比如中建、中铁、中冶、中电建、中交建等大型施工单位。合作案例是没法骗人的当然，建筑施工...
# 546    recent -  质量教育培训和技术交底，严格执行培训考核合格后持证上岗，严格按照施工工艺...
# 666    《水运工程》2015年第11期 | 王新学 林少波 中交股份总承包经营分公司  经验为主,实...
# 922     - 这些基本涵盖了建筑施工现场容易发生安全事故的危险源。 此次该公司采购的安全体验馆设备有...
# Name: content, dtype: object
# cluster 46
# 0.016746884147421478
# ['中交建', '中铁', '中交', '2010', '苏通', '跨海大桥', '长江大桥', '中房', '集团', '胜出']
# 270    2015年 - 中交建在这一轮博弈中胜出。2010年8月，国资委宣布，将以无偿行政划拨的方式...
# 336    2017年 - 中交建在这一轮博弈中胜出。2010年8月，国资委宣布，将以无偿行政划拨的方式...
# 827    2015年 - 中交建在这一轮博弈中胜出。2010年8月，国资委宣布，将以无偿行政划拨的方式...
# 899    2017年 - 中交建在这一轮博弈中胜出。2010年8月，国资委宣布，将以无偿行政划拨的方式...
# Name: content, dtype: object
# cluster 12
# 0.02005966379192725
# ['2016', '中交', '所属', '少计', '2018', '列支', '福利费', '违约金', '13', '打脸']
# 660    2018年 - 8．2016年，所属中交股份总部、中交城市投资控股有限公司3个工程项目对  ...
# 682    2018年 - 6．2016年，中交股份总部及所属5家企业未按规定计提坏账准备等，造成多计利...
# 692    2018年 - 6．2016年，中交股份总部及所属5家企业未按规定计提坏账准备等，  8．2...
# 699    2018年 - 至2016年底，所属中国交通建设股份有限公司（以下简称中交股份）多  6．2...
# Name: content, dtype: object
# cluster 4
# 0.01613565717289491
# ['交通', '公告', '误导性', '有限公司', '建设', '股份', '遗漏', '2018', '董事', '陈述']
# 368    2015年 - 中国交通建设股份有限公司（以下简称本公司或公司）董事会及全体董事. 保证本公...
# 402    2018年 - 中国交通建设股份有限公司（以下简称本公司或公司）董事会及全体董事保证本公告内...
# 405    2018年 - 中国交通建设股份有限公司（以下简称本公司或公司）董事会及全体董事保证本公告内...
# 434    2017年 - 中国交通建设股份有限公司（以下简称本公司或公司）董事会及全体董事. 保证本公...
# Name: content, dtype: object
# cluster 349
# 0.021946864119207196
# ['巴拿马', '陈思敏', '央企遭', '废标', '法轮功', '谋杀罪', 'recent', '告上', '中共', '说起']
# 42     recent - 在巴拿马公共工程部（MOP）当时收到的4份报价中，中交股份这一组给出的  ...
# 46     2 - 在巴拿马公共工程部（MOP）当时收到的四份报价中，中交股份这一组给出的  等十几个国...
# 304    recent - 基于上述证据，中交建和中港湾承建的哈尔滨阳明滩大桥被指豆腐渣工程。  等十...
# 443    recent - 开标结果，得标者〝巴拿马第四大桥合作组〞是由中国交通建设股份有限  坍塌死...
# Name: content, dtype: object
# cluster 6
# 0.027782118490353516
# ['之诉', '中交', '网站', '承担', 'beplay', '上述', '侵权', '刑事责任', '法律责任', '任何']
# 557    中交股份保留未经通知随时更新下列条款的权利，这些更新将同样也约束您。  相关国际条约的保护，...
# 580    本网站由中国交通建设股份有限beplay黑平台（以下简称"中交股份"）创设。  性法律文件及...
# 593    本网站的资料、信息及其他内容由中交股份提供，任何人进入本网站、阅读任何内容、从本网站○  及...
# 797    本网站由中交建融租赁有限公司（以下简称"中交租赁"）创设。  国际条约的保护，任何对上述权利...
# Name: content, dtype: object
# cluster 214
# 0.030873457484112757
# ['马来西亚', '马哈蒂尔', '中交建', '总理', '新政府', '2018', '丑闻', '中资', '项目', '执政']
# 321    2018年 - 中交建4日证实，马来西亚政府要求谈判期间停止工程，中交建对此感到遗憾，促请马...
# 340    2 - 马来西亚总理马哈蒂尔7月初就在两日内暂停4项中国参与兴建的项目，包括中交建参建的东海...
# 852    2018年 - 日前，马来西亚新总理马哈蒂尔宣布，新政府将冒着巨额违约金的风险， . 因为不...
# 878    recent - 这一消息并不意外。再次执政的马来西亚总理马哈蒂尔·穆罕默德(Mahathi...
# Name: content, dtype: object
# cluster 8
# 0.025304609973647738
# ['英大', '基金', '2012', '中交', '有限公司', '信托', '管理', '出资', '中国证监会', '股份']
# 37    英大基金管理有限公司，也称英大资本、英大基金，是一家2012年，经中国证监会批准，在北京成立...
# 38    2012年，经中国证监会批准，英大基金管理有限公司在北京正式成立。  英大基金注册资金2亿元...
# 49    2012年，经中国证监会批准，英大基金管理有限公司在北京正式成立。  国际信托有限责任公司（...
# 54    2012年，经中国证监会批准，英大基金管理有限公司在北京正式成立。  英大基金注册资金2亿元...
# Name: content, dtype: object
# cluster 266
# 0.025684059862220047
# ['停工', '马来西亚', '遵守', '叫停', '中交建', '别无选择', '尊重', '中资', '2018', 'recent']
# 224    2018年 - 据悉，MRL致中交建的信件中，今次停工涉及「国家利益」等多个理由。中交建表示...
# 332    recent - 中交建称：“我们尊重并遵守马来西亚法律，在这种情况下，我们别无选择，只能遵...
# 333    2018年 - 中交建证实收到停工的通知，他们在声明中指，公司尊重并遵守马来西亚法律，因此别...
# 887    recent - 这一消息并不意外。  中交建称：“我们尊重并遵守马来西亚法律，在这种情况下...
# Name: content, dtype: object
# cluster 38
# 0.005581472969514007
# ['中望', 'WWW', 'ZWCAD', '中交', '三局', '龙腾', '企业形象', '侥幸心理', '知名企业', '股份']
# 71     如果抱有侥幸心理，一旦侵权纠纷曝光，企业形象将受到严重损害，甚至还会带来  招商地产、国投集...
# 100    如果抱有侥幸心理，一旦侵权纠纷曝光，企业形象将受到严重损害，甚至还会带来  招商地产、国投集...
# 643    如果抱有侥幸心理，一旦侵权纠纷曝光，企业形象将受到严重损害，甚至还会带来  招商地产、国投集...
# Name: content, dtype: object
# cluster 54
# 0.031750224412179555
# ['中交', '游戏', '2018', '平台', '手机', '民工', '赌博', '里程', '论文', '双块']
# 59     要说游戏大平台【w83kk.com】,玩真钱的手机赌博游戏是最有实力的之一,【适合玩游戏的手...
# 691    2018年 - 据悉，以上几位四川民工曾在台江县台盘乡中交股份沪昆客专贵州段工程第三项目务工...
# 701    2018年 - 中交股份新建云桂铁路（广西段）YGZQ-2标段无砟轨道起点里程DK124+8...
# Name: content, dtype: object
# cluster 225
# 0.01531505966097632
# ['交通', '有限公司', '建设', '股份', '国务院', '中交', '2006', '百科', '中国', '国资委']
# 356    中国交通建设股份有限公司（以下简称中交股份）成立于2006年，经国务院批准，由中国交通建设集...
# 448    中国交通建设股份有限公司（以下简称中交股份）成立于2006年，经国务院批准，由中国交通建设集...
# 636    2018年 - 中国交通建设股份有限公司（以下简称中交股份）成立于2006年，经国务院批准，...
# Name: content, dtype: object
# cluster 82
# 0.027515056533200962
# ['中交建', '东海岸', '马来西亚', '大马', '项目', '发声明', '表示遗憾', '2018', '铁路', '工程']
# 213    2018年 - 若马来西亚政府终止有关项目，须支付约53亿美元的赔偿和罚款。不过有媒体引述消...
# 753    2018年 - 中国「一带一路」投资项目再遇挫折，大陆国企「中交建」在马来西亚承建的「东海岸...
# 835    中国「一带一路」投资项目再遇挫折，大陆国企「中交建」在马来西亚承建的「东海岸铁路」项目，被大...
# Name: content, dtype: object
# cluster 174
# 0.02734450788122446
# ['德胜', '276', '丁慧平', '复垦', '荒废', '松江', '大学', '乡镇', '纠纷', '扬州']
# 234    2013年 - 原标题[中国交建子公司陷复垦纠纷上海松江276亩耕地荒废超2年]. 每日经济...
# 454    德胜街道辖区现有北京普天德胜、北京康华伟业等8家孵化器企业，及中国交通建设股份有限公司、中国...
# 614    中国乡镇工业污染物治理市场的改革途径,《扬州大学税务学院学报》,2007年第3期。 期刊->...
# Name: content, dtype: object
# cluster 151
# 0.015389426512120954
# ['2017', '国企', '湾仔', '廉政公署', '中交建', '香港', '会展', '办公大楼', '立场', '搜查']
# 204    2017年 - 在香港上市的大陆国企中国交通建设（中交建）昨日（）发出公佈，于2017年，廉...
# 750    2017年 - 在香港上市的大陆国企中国交通建设（中交建）昨日（）发出公佈，于2017年，廉...
# 862    2017年 - 在香港上市的大陆国企中国交通建设（中交建）7日发出公布，于2017年，廉政公...
# Name: content, dtype: object
# cluster 32
# 0.008134776011891488
# ['中交建', '多米尼加', '2018', '交建', '康克玛特', '多米尼加共和国', '公司', '拓展', '获知', '中标']
# 207    2018年 - 中交建拓展多米尼加市场取得突破---记者从中国交建南部美洲区域公司获知，该公...
# 251    2018年 - 记者从中国交建南部美洲区域公司获知，该公司旗下康克玛特设计咨询公司近日中标多...
# 839    2018年 - 新华社圣保罗电记者从中国交建南部美洲区域公司获知，该公司旗下康克玛特设计咨询...
# Name: content, dtype: object
# cluster 79
# 0.01959653865440387
# ['中交', '豆腐渣', '污染', '硬伤', '股份', '披露', '为何', '公路', '上市', '事件']
# 554    2011年 - [神州股票资讯]中交股份豆腐渣公路污染事件被披露两硬伤为何能上市  中国交通...
# 560    2011年 - 中交股份豆腐渣公路污染披露两硬伤为何能上市  中国交通建设股份有限公司(下称...
# 563    中交股份豆腐渣公路污染事件被披露两硬伤为何能上市, 点击查看中国交通  眼前有，甘肃豆腐渣式...
# Name: content, dtype: object
# cluster 155
# 0.015476850761821826
# ['绿城', '2015', '央企中', '交建系', '中交建', '宋卫平', '晋者', '中交建系', '中交', '换血']
# 255    2015年 - 按照约定，中交建将全面介入绿城的财务管理、成本管理、战略管理等关键部门，以宋...
# 803    2015年 - 按照约定，中交建将全面介入绿城的财务管理、成本管理、战略管理等关键部门，以宋...
# 849    2015年 - 曾经的并列第一大股东九龙仓对此事的公开表态是，“九龙仓早前知悉中交建有意进一...
# Name: content, dtype: object
# cluster 345
# 0.02213773362604778
# ['中交建', 'Aecon', '15', '2018', '否决', '并购', '丑闻', '加拿大', '亿加元', '收购']
# 335    2018年 - Ltd，下文简称“中交建”）提出的以15亿加币收购加拿大建筑巨头Aecon ...
# 774    2018年 - 加拿大政府：国家安全考量否决中交建15亿加元收购Aecon集团计划  中交建...
# 786    2018年 - 联邦以国家安全为由 否决中交建并购Aecon  具体威胁没解释中交建计划以1...
# Name: content, dtype: object

# %%
list_index = list(google_df['labels'].value_counts().isin([1]).index)

# %%
google_df[google_df['labels'].isin(list_index)]['content']
# Out:
# 0      2018年 - 根据《中华人民共和国审计法》的规定，2017年5月至6月，审计署对中国  至...
# 1      拟募资200亿元，或为A股年内最大IPO项目的中国交通建设股份有限公司（以下简称中交股份），...
# 2      2011年 - 中国网讯中国交通建设股份有限公司（以下称中交股份）因被指孙公司有染“豆腐渣”...
# 3      2018年 - 6.2010年至审计时，所属中交股份19名职工投资入股的公司违规与集团内部企...
# 904    2018年 - 中新网多伦多电中国驻加拿大大使卢沙野于当地时间在使馆就加方否决中交建收购加爱...
# 905    recent - 财经,港股风云,消息和港股风云最新消息标题为：中交建现跌近2% 证实大马东...
# 906    2018年 - 国际在线报道（中国国际广播电台驻巴西记者郭昊）：巴西当地时间，由中国交通建设...
# 907    recent - 2012年，黑龙江哈尔滨阳明滩大桥发生匝道坍塌死伤事故，  基于上述证据，...
# 908    2017年 - 一是铁路建设运输类国企债——中交建、中铁建，以及能源资源基础建设类国企债——...
# 909    金隅股份、中交建回归A股机构“潜伏”获利颇丰. 早在金隅H股上市之初，在招股书中承诺公司上市...
# 910    中交建遗憾东铁暂停工．“实质工作进展良好”  总检察长汤米汤姆斯表示，对于前首相拿督斯里纳吉...
# 911    recent - 纳吉将这条六百公里的铁路交给中国的中交建承办。在中方的财权控制之下，征地费...
# 912    2017年 - 1、中能建湖南院签约阿根廷潘帕100MW风电项目. 近日，中能建湖南院签署阿...
# 913    2018年 - 据马来西亚《新海崃时报》（New Straits Times）昨日（4日）报...
# 914     - 争取中交建（霸州）新能源汽车开工建设、加快中公高科霸州产业示范基地建设进度、确保霸州云...
# 915     -  科技奖7项（第一完成人） 原中国铁路通信信号集团公司党委、纪委领导营业绩产生积极影响...
# 916    但现在加中关系似乎冷淡下来，加政府对进一步发展对华关系更加犹豫，它阻止了中交建收购加爱康集团...
# 917    2 - 但现在加中关系似乎冷淡下来，加政府对进一步发展对华关系更加犹豫，它阻止了中交建收购加...
# 918    1 - 但现在加中关系似乎冷淡下来，加政府对进一步发展对华关系更加犹豫，它阻止了中交建收购加...
# 919    福建中交建新型环保建材有限公司怎么样? 安徽休宁县公益用地建别墅奢华装修实景求曝光在公益用地...
# 920    1 - 实际上美国拿所谓「商业间谍」、「侵犯智慧财产权」、「偷窃技术」等  在西方国家被使用...
# 921     - 贵州2017年破获知识产权侵权案件250余起. - chinanews.com  别被...
# 922     - 这些基本涵盖了建筑施工现场容易发生安全事故的危险源。 此次该公司采购的安全体验馆设备有...
# 923    2018-07-03 00:00:00.0|, 中国交建成功举办投资业务专题反向路演. 20...
# 924     - 社会保障理事会同交建也共同发起成立了规模150亿元的“中交建壹期”来投向基础建设的pp...
# 925    recent - 社会保障理事会同交建也共同发起成立了规模150亿元的“中交建壹期”来投向基...
# 926     - 过低的价格、夸张的描述、私人银行账户等都有可能是虚假信息，请采购商谨慎对待，谨防欺诈，...
# 927    公司动向：与腾讯（700）签署战略合作框架协议，全力发挥各自在交通建设和互联网领域的优势，融...
# 928     - 航运物流方面，在成功吸引中远中船中海油中外运中交建神华等航运物流央企落户的同时，大力推...
# 929     - 猎聘温馨提示：用人单位发布虚假招聘广告信息，或者以各种名义向求职者收取费用（ 如培训费...
# 930    中华网JK平台注册为您提供印度人聚合阅读,主要包括最新的印度人相关JK平台注册,印度人图片,...
# Name: content, Length: 931, dtype: object
